# %%
#We use statistics in a lot of different ways in data science, and on this lecture
#Refresh the knowledge of hypothesis testing
#The goal of hypothesis testing is to determine if, for instance, the two different conditions we have in an experiment 
#have resulted in different impacts

#Let's import our usual numpy and pandas libraries
import numpy as np
import pandas as pd

#Now let's bring in some new libraries from scipy
from scipy import stats

#Let's see an axample of this; we're going to use some grade data
df=pd.read_csv('grades.csv')
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# ...

# %%
print("There are {} rows and {} columns".format(df.shape[0], df.shape[1]))
# Out:
# There are 2315 rows and 13 columns

# %%
early_finishers=df[pd.to_datetime(df['assignment1_submission']) < '2016']
early_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 5  D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 8  C9D51293-BD58-F113-4167-A7C0BAFCB6E5          66.595568
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 4  2015-12-13 17:06:10.750000000          51.491040
# 5  2015-12-28 04:35:32.836000000          64.052550
# 8  2015-12-25 02:29:28.415000000          52.916454
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 4  2015-12-14 12:25:12.056000000          41.932832
# 5  2016-01-03 21:05:38.392000000          64.752550
# ...

# %%
late_finishers=df[~df.index.isin(early_finishers.index)]
late_finishers.head()
# Out:
#                              student_id  assignment1_grade  \
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 6  3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7  F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
# 9  E2C617C2-4654-622C-AB50-1550C4BE42A0          59.270882
#
#           assignment1_submission  assignment2_grade  \
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 6  2016-03-05 11:05:25.408000000          69.998995
# 7  2016-01-24 18:24:25.619000000          72.518481
# 9  2016-03-06 12:06:26.185000000          59.270882
#
#           assignment2_submission  assignment3_grade  \
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# 6  2016-03-09 07:29:52.405000000          55.999196
# 7  2016-01-27 13:37:12.943000000          65.266633
# ...

# %%
print(early_finishers['assignment1_grade'].mean())
print(late_finishers['assignment1_grade'].mean())
# Out:
# 74.94728457024303
# 74.0450648477065

# %%
#Let's bring in our ttest_ind function
from scipy.stats import ttest_ind

#Let's run this fucntion with our two populations, looking at the assignment 1 grades
ttest_ind(early_finishers['assignment1_grade'], late_finishers['assignment1_grade'])
# Out:
# Ttest_indResult(statistic=1.322354085372139, pvalue=0.1861810110171455)

# %%
#Why don't we check the other asignment grades?
print(ttest_ind(early_finishers['assignment2_grade'], late_finishers['assignment2_grade']))
print(ttest_ind(early_finishers['assignment3_grade'], late_finishers['assignment3_grade']))
print(ttest_ind(early_finishers['assignment4_grade'], late_finishers['assignment4_grade']))
print(ttest_ind(early_finishers['assignment5_grade'], late_finishers['assignment5_grade']))
print(ttest_ind(early_finishers['assignment6_grade'], late_finishers['assignment6_grade']))
# Out:
# Ttest_indResult(statistic=1.2514717608216366, pvalue=0.2108889627004424)
# Ttest_indResult(statistic=1.6133726558705392, pvalue=0.10679998102227865)
# Ttest_indResult(statistic=0.049671157386456125, pvalue=0.960388729789337)
# Ttest_indResult(statistic=-0.05279315545404755, pvalue=0.9579012739746492)
# Ttest_indResult(statistic=-0.11609743352612056, pvalue=0.9075854011989656)

# %%
#Let's see a simulation of this. First, lets create a data frame of 100 columns, each with 100 numbers
df1=pd.DataFrame([np.random.random(100) for x in range(100)])
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.760512  0.323673  0.962862  0.283688  0.148889  0.171829  0.114984
# 1  0.260906  0.280526  0.369102  0.413145  0.427796  0.334462  0.450670
# 2  0.427102  0.723574  0.410606  0.449056  0.259413  0.092197  0.961362
# 3  0.022787  0.911229  0.542368  0.041472  0.006610  0.461519  0.530809
# 4  0.793648  0.480801  0.681378  0.792793  0.458810  0.487270  0.702016
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.052327  0.413609  0.626415  ...  0.654233  0.751505  0.010319  0.866060
# 1  0.767434  0.168029  0.575110  ...  0.726547  0.972696  0.629406  0.276823
# 2  0.366911  0.503337  0.156402  ...  0.022181  0.299255  0.454646  0.383983
# 3  0.483083  0.905219  0.836651  ...  0.011505  0.095635  0.477469  0.139975
# 4  0.467590  0.548272  0.495736  ...  0.318567  0.411307  0.984078  0.987504
#
#          94        95        96        97        98        99
# ...

# %%
#Ok, let's create a second dataframe
df2=pd.DataFrame([np.random.random(100) for x in range(100)])

# %%
#Let's write this in a fuction called test_columns
def test_columns(alpha=0.1):
    num_diff=0
    for col in df1.columns:
        teststat,pval=ttest_ind(df1[col],df2[col])
        if pval<=alpha:
            print("Col {} is statistically significantly different at alpha={}, pval={}".format(col,alpha,pval))
            num_diff=num_diff+1
    print("Total number different was {}, which is {}%".format(num_diff,float(num_diff)/len(df1.columns)*100))
    
test_columns()
# Out:
# Col 17 is statistically significantly different at alpha=0.1, pval=0.05490054222943192
# Col 18 is statistically significantly different at alpha=0.1, pval=0.0853678941350557
# Col 28 is statistically significantly different at alpha=0.1, pval=0.07116259889869196
# Col 46 is statistically significantly different at alpha=0.1, pval=0.04769679942663894
# Col 48 is statistically significantly different at alpha=0.1, pval=0.04006102710256737
# Col 50 is statistically significantly different at alpha=0.1, pval=0.014295928405025683
# Col 55 is statistically significantly different at alpha=0.1, pval=0.07961872333662742
# Col 64 is statistically significantly different at alpha=0.1, pval=0.05072689818137229
# Col 80 is statistically significantly different at alpha=0.1, pval=0.03870915624301147
# Col 81 is statistically significantly different at alpha=0.1, pval=0.019635192754425955
# Col 85 is statistically significantly different at alpha=0.1, pval=0.06826327424320641
# ...

# %%
test_columns(0.05)
# Out:
# Col 46 is statistically significantly different at alpha=0.05, pval=0.04769679942663894
# Col 48 is statistically significantly different at alpha=0.05, pval=0.04006102710256737
# Col 50 is statistically significantly different at alpha=0.05, pval=0.014295928405025683
# Col 80 is statistically significantly different at alpha=0.05, pval=0.03870915624301147
# Col 81 is statistically significantly different at alpha=0.05, pval=0.019635192754425955
# Total number different was 5, which is 5.0%

# %%
df2=pd.DataFrame([np.random.chisquare(df=1,size=100) for x in range(100)])
test_columns()
# Out:
# Col 0 is statistically significantly different at alpha=0.1, pval=2.8359063474110376e-06
# Col 1 is statistically significantly different at alpha=0.1, pval=3.118099556398223e-06
# Col 2 is statistically significantly different at alpha=0.1, pval=0.003196390528479152
# Col 3 is statistically significantly different at alpha=0.1, pval=0.0009255693133413374
# Col 4 is statistically significantly different at alpha=0.1, pval=0.014726714453919416
# Col 5 is statistically significantly different at alpha=0.1, pval=0.0013243430588624962
# Col 6 is statistically significantly different at alpha=0.1, pval=0.001235594281719654
# Col 7 is statistically significantly different at alpha=0.1, pval=0.00018081327001404548
# Col 8 is statistically significantly different at alpha=0.1, pval=0.0003766910166457331
# Col 9 is statistically significantly different at alpha=0.1, pval=6.107119355019835e-06
# Col 10 is statistically significantly different at alpha=0.1, pval=0.00020952497886835516
# ...
